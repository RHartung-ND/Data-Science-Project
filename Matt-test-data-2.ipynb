# %% [markdown]
# - Get all the new data from imdb & add the budget and revenue stuff.

# %%
import streamlit as st
import pandas as pd

data_frames = []

# %%
title_basics_df = pd.read_csv("movie-data/imdb-pre-processed/title.basics.tsv", sep="\t", dtype=str)
data_frames.append(title_basics_df)

print(title_basics_df.info())
print(title_basics_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11475506 entries, 0 to 11475505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 788.0+ MB
# None
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
# ...

# %%
title_akas_df = pd.read_csv("movie-data/imdb-pre-processed/title.akas.tsv", sep="\t", dtype=str)
data_frames.append(title_akas_df)

print(title_akas_df.info())
print(title_akas_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51312073 entries, 0 to 51312072
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         object
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: object(8)
# memory usage: 3.1+ GB
# None
#      titleId ordering                      title region language        types  \
# 0  tt0000001        1                 Carmencita     \N       \N     original
# 1  tt0000001        2                 Carmencita     DE       \N           \N
# 2  tt0000001        3                 Carmencita     US       \N  imdbDisplay
# 3  tt0000001        4  Carmencita - spanyol tánc     HU       \N  imdbDisplay
# 4  tt0000001        5                 Καρμενσίτα     GR       \N  imdbDisplay
#
#       attributes isOriginalTitle
# ...

# %%
title_crew_df = pd.read_csv("movie-data/imdb-pre-processed/title.crew.tsv", sep="\t", dtype=str)
data_frames.append(title_crew_df)

print(title_crew_df.info())
print(title_crew_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11475506 entries, 0 to 11475505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 788.0+ MB
# None
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
# ...

# %%
title_episode_df = pd.read_csv("movie-data/imdb-pre-processed/title.episode.tsv", sep="\t", dtype=str)
data_frames.append(title_episode_df)

print(title_episode_df.info())
print(title_episode_df.head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 title_episode_df = pd.read_csv("movie-data/imdb-pre-processed/title.basics.tsv", sep="\t", dtype=str)
#       2 data_frames.append(title_episode_df)
#       4 print(title_episode_df.info())
#
# ...

# %%
title_principals_df = pd.read_csv("movie-data/imdb-pre-processed/title.principals.tsv", sep="\t", dtype=str)
data_frames.append(title_principals_df)

print(title_principals_df.info())
print(title_principals_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11475506 entries, 0 to 11475505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 788.0+ MB
# None
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
# ...

# %%
title_ratings_df = pd.read_csv("movie-data/imdb-pre-processed/title.ratings.tsv", sep="\t", dtype=str)
data_frames.append(title_ratings_df)

print(title_ratings_df.info())
print(title_ratings_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11475506 entries, 0 to 11475505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 788.0+ MB
# None
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
# ...

# %%
name_basics_df = pd.read_csv("movie-data/imdb-pre-processed/name.basics.tsv", sep="\t", dtype=str)
data_frames.append(name_basics_df)

print(name_basics_df.info())
print(name_basics_df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11475506 entries, 0 to 11475505
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 788.0+ MB
# None
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
# ...
